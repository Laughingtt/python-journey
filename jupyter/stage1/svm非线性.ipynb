# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.svm import SVC

# %%
X = np.random.randn(300,2)
plt.scatter(X[:,0],X[:,1])

# %%
### 属性组合，可以将数据分开
X_ = X[:,0]*X[:,1]
y = X_>0
plt.scatter(X[:,0],X[:,1],c=y)

# %%
# rbf 符合高斯分布
svc = SVC(kernel="rbf")
svc.fit(X,y)
# Out:
# SVC()

# %%
svc.coef_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-a8dadb2081e3> in <module>
# ----> 1 svc.coef_
#
# ~/.pyenv/versions/3.7.5/lib/python3.7/site-packages/sklearn/svm/_base.py in coef_(self)
#     490     def coef_(self):
#     491         if self.kernel != 'linear':
# --> 492             raise AttributeError('coef_ is only available when using a '
#     493                                  'linear kernel')
#     494
#
# AttributeError: coef_ is only available when using a linear kernel

# %%
svc.intercept_
# Out:
# array([-0.0024431])

# %%
x1 = np.linspace(-3,3,100) #100个横坐标
y1 = np.linspace(-3,3,100) #100个纵坐标
X1,Y1 = np.meshgrid(x1,y1) #10000个坐标,其中一个横坐标对应100个纵坐标

# %%
X_test = np.concatenate([X1.reshape(-1,1),Y1.reshape(-1,1)],axis=-1)
plt.scatter(X_test[:,0],X_test[:,1])

# %%
X_test
# Out:
# array([[-3.        , -3.        ],
#        [-2.93939394, -3.        ],
#        [-2.87878788, -3.        ],
#        ...,
#        [ 2.87878788,  3.        ],
#        [ 2.93939394,  3.        ],
#        [ 3.        ,  3.        ]])

# %%
y_ = svc.predict(X_test)

# %%
y_
# Out:
# array([ True,  True,  True, ...,  True,  True,  True])

# %%
plt.figure(figsize=(6,6))
plt.scatter(X_test[:,0],X_test[:,1],c=y_)

# %%
# 求划分的距离

d_ = svc.decision_function(X_test)

# %%
d_
# Out:
# array([0.08955224, 0.09956901, 0.11055547, ..., 0.07024409, 0.062472  ,
#        0.05546682])

# %%
plt.figure(figsize=(6,6))

plt.contourf(X1,Y1,d_.reshape(100,100))

# %%
x1 = np.linspace(-3,3,100)
x1.shape
# Out:
# (100,)
